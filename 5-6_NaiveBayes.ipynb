# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import nltk
from nltk import word_tokenize, sent_tokenize, pos_tag
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import os
import pandas as pd
import re
from string import punctuation
from sklearn.feature_extraction.text import TfidfVectorizer
from datetime import datetime

# %%
english_stopwords = set(stopwords.words('english') + list(punctuation) + ['..','...','nbsp','n\'t'])

# %%
lemmatizer = WordNetLemmatizer()

# %%
df = pd.read_csv('blogtext.csv')

# %%
#Gathering blogs by all genders between 20-29
new_df = df[(df['age'] > 19) & (df['age'] < 30)]

# %%
sorted_df = new_df.groupby('id').agg({
    'id': 'first',
    'gender': 'first',
    'age': 'first',
    'text': '\n'.join
})

# %%
sorted_df
# Out:
#               id  gender  age  \
# id
# 5114        5114    male   25
# 7596        7596    male   26
# 8349        8349    male   24
# 9289        9289    male   23
# 9470        9470    male   25
# ...          ...     ...  ...
# 4335239  4335239  female   27
# 4335684  4335684    male   27
# 4336267  4336267    male   27
# 4336547  4336547    male   23
# 4336651  4336651  female   25
#
#                                                       text
# id
# 5114                  Slashdot raises lots of  urlLink ...
# 7596            Every day should be a half day.  Took t...
# 8349            Ever wondered what a  urlLink Bad head,...
# 9289                  testing         \n             wi...
# 9470            Yet another TV Channel. This time it's ...
# ...                                                    ...
# 4335239         Have you been watching the Olympics?  I...
# 4335684             Ok, while driving fast up I-88, I w...
# 4336267         Will discuss Spy Fly which is being dev...
# 4336547         Well, my first post.  I guess it would ...
# 4336651         Not really to state that I am an expert...
#
# [8086 rows x 4 columns]

# %%
def manipulate_text(text):
    text = text.lower()
    toke_text = word_tokenize(text)
    wordlist = []
    for word in toke_text:
        if word not in english_stopwords:
            wordlist.append(word)
    wordlist2 = []
    for eachword in wordlist:
        wordlist2.append(lemmatizer.lemmatize(eachword))
    text = [' '.join(wordlist2)]
    text = str(text)
    return text

# %%
sorted_df['text'] = sorted_df['text'].apply(manipulate_text)

# %%
sorted_df
# Out:
#               id  gender  age  \
# id
# 5114        5114    male   25
# 7596        7596    male   26
# 8349        8349    male   24
# 9289        9289    male   23
# 9470        9470    male   25
# ...          ...     ...  ...
# 4335239  4335239  female   27
# 4335684  4335684    male   27
# 4336267  4336267    male   27
# 4336547  4336547    male   23
# 4336651  4336651  female   25
#
#                                                       text
# id
# 5114     ["slashdot raise lot urllink interesting thoug...
# 7596     ["every day half day took afternoon hit dentis...
# 8349     ["ever wondered urllink bad head head crash ha...
# 9289     ["testing every passing day hard imagine going...
# 9470     ["yet another tv channel time 's called zoom c...
# ...                                                    ...
# 4335239  ["watching olympics got really nervous 100m hu...
# 4335684  ["ok driving fast i-88 thinking thinking heave...
# 4336267  ["discus spy fly developed university californ...
# 4336547  ["well first post guess would proper start tel...
# 4336651  ["really state expert go world live wanted sha...
#
# [8086 rows x 4 columns]

# %%
sorted_df['GenderCode'] = sorted_df['gender'].apply(lambda x: 1 if x == 'female' else 0)

# %%
sorted_df
# Out:
#               id  gender  age  \
# id
# 5114        5114    male   25
# 7596        7596    male   26
# 8349        8349    male   24
# 9289        9289    male   23
# 9470        9470    male   25
# ...          ...     ...  ...
# 4335239  4335239  female   27
# 4335684  4335684    male   27
# 4336267  4336267    male   27
# 4336547  4336547    male   23
# 4336651  4336651  female   25
#
#                                                       text  GenderCode
# id
# 5114     ["slashdot raise lot urllink interesting thoug...           0
# 7596     ["every day half day took afternoon hit dentis...           0
# 8349     ["ever wondered urllink bad head head crash ha...           0
# 9289     ["testing every passing day hard imagine going...           0
# 9470     ["yet another tv channel time 's called zoom c...           0
# ...                                                    ...         ...
# 4335239  ["watching olympics got really nervous 100m hu...           1
# 4335684  ["ok driving fast i-88 thinking thinking heave...           0
# 4336267  ["discus spy fly developed university californ...           0
# 4336547  ["well first post guess would proper start tel...           0
# 4336651  ["really state expert go world live wanted sha...           1
#
# [8086 rows x 5 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(sorted_df.text, sorted_df.GenderCode, random_state=1)

# %%
tfidf_vectorizer = TfidfVectorizer(use_idf=True)
X_train_tf = tfidf_vectorizer.fit_transform(X_train)
X_test_tf = tfidf_vectorizer.transform(X_test)

# %%
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train_tf, Y_train)
predictions = naive_bayes.predict(X_test_tf)

# %%
print('Accuracy: ', accuracy_score(Y_test, predictions))
# Out:
# Accuracy:  0.7111770524233432
